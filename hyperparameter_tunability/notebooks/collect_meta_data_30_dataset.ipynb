# %% [markdown]
# ### intro
# In this notebook, we will extract some meta-data regrad to all datasets

# %%
import pandas as pd
import numpy as np
from os import listdir
from os.path import isfile, join
import openml
import pandas as pd
from openml.datasets import edit_dataset, fork_dataset, get_dataset

# %%
mypath="../datasets"
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]

# %%
files= [ file[:-4] for file in onlyfiles]
files
# Out:
# ['donut1',
#  'diabetes',
#  'qsar-biodeg',
#  'curves2',
#  'spambase',
#  'disk_4000n',
#  'haberman',
#  'dense-disk-5000',
#  'eeg-eye-state',
#  'disk_4600n',
#  'Amazon_employee_access',
#  'phoneme',
#  'disk_1000n',
#  'Transfusion',
#  'breast-w',
#  'electricity',
#  'chainlink',
#  'disk_4500n',
#  'dense-disk-3000',
#  'engytime',
#  'disk_5000n',
#  'jain',
#  'banana',
#  'Spectf',
#  'atom',
#  'parkinsons',
#  'donut2',
#  'circle',
#  'flame']

# %%
openml_list = openml.datasets.list_datasets()  # returns a dict
datalist = pd.DataFrame.from_dict(openml_list, orient="index")

# %%
datalist.columns
# Out:
# Index(['did', 'name', 'version', 'uploader', 'status', 'format',
#        'MajorityClassSize', 'MaxNominalAttDistinctValues', 'MinorityClassSize',
#        'NumberOfClasses', 'NumberOfFeatures', 'NumberOfInstances',
#        'NumberOfInstancesWithMissingValues', 'NumberOfMissingValues',
#        'NumberOfNumericFeatures', 'NumberOfSymbolicFeatures'],
#       dtype='object')

# %%
dataset_name=  pd.DataFrame (files, columns = ['dataset_name'])
dataset_name
# Out:
#               dataset_name
# 0                   donut1
# 1                 diabetes
# 2              qsar-biodeg
# 3                  curves2
# 4                 spambase
# 5               disk_4000n
# 6                 haberman
# 7          dense-disk-5000
# 8            eeg-eye-state
# 9               disk_4600n
# 10  Amazon_employee_access
# 11                 phoneme
# 12              disk_1000n
# 13             Transfusion
# 14                breast-w
# 15             electricity
# 16               chainlink
# 17              disk_4500n
# 18         dense-disk-3000
# 19                engytime
# 20              disk_5000n
# 21                    jain
# 22                  banana
# 23                  Spectf
# 24                    atom
# 25              parkinsons
# 26                  donut2
# 27                  circle
# 28                   flame

# %%
df_out =datalist.iloc[:0,:].copy()
df_out
# Out:
# Empty DataFrame
# Columns: [did, name, version, uploader, status, format, MajorityClassSize, MaxNominalAttDistinctValues, MinorityClassSize, NumberOfClasses, NumberOfFeatures, NumberOfInstances, NumberOfInstancesWithMissingValues, NumberOfMissingValues, NumberOfNumericFeatures, NumberOfSymbolicFeatures]
# Index: []

# %%
new_df= datalist.loc[datalist['name'].str.contains("plane", case=False)]
new_df
# Out:
#          did                   name  version uploader  status format  \
# 152      152     Hyperplane_10_1E-3        1        1  active   ARFF
# 153      153     Hyperplane_10_1E-4        1        1  active   ARFF
# 215      215               2dplanes        1        1  active   ARFF
# 727      727               2dplanes        2        2  active   ARFF
# 1197    1197          BNG(2dplanes)        1        1  active   ARFF
# 43122  43122             Hyperplane        1     5348  active   ARFF
# 43849  43849  2018-Airplane-Flights        1    30125  active   arff
#
#        MajorityClassSize  MaxNominalAttDistinctValues  MinorityClassSize  \
# 152             500007.0                          2.0           499993.0
# 153             500166.0                          2.0           499834.0
# 215                  NaN                          NaN                NaN
# 727              20420.0                          2.0            20348.0
# ...

# %%
df_out=df_out.append(new_df,ignore_index= True)

# %%
df_out
# Out:
#     did          name  version uploader  status format  MajorityClassSize  \
# 0   343  white-clover        1        2  active   ARFF               38.0
# 1  1009  white-clover        2        2  active   ARFF               38.0
#
#    MaxNominalAttDistinctValues  MinorityClassSize  NumberOfClasses  \
# 0                          7.0                1.0              4.0
# 1                          7.0               25.0              2.0
#
#    NumberOfFeatures  NumberOfInstances  NumberOfInstancesWithMissingValues  \
# 0              32.0               63.0                                 0.0
# 1              32.0               63.0                                 0.0
#
#    NumberOfMissingValues  NumberOfNumericFeatures  NumberOfSymbolicFeatures
# 0                    0.0                     27.0                       5.0
# 1                    0.0                     27.0                       5.0

# %%
i=0
not_in=[]
ls_out=[]
for str in dataset_name["dataset_name"].tolist():
    new_df= datalist.loc[datalist['name'].str.contains(str, case=False)]
    
    if not new_df.empty:
       df_out= df_out.append(new_df)

# %%
df_out = df_out.drop_duplicates(subset=['name'], keep='first')

# %%
df_out
# Out:
#          did                                               name  version  \
# 37        37                                           diabetes        1
# 212      212                                   diabetes_numeric        1
# 4541    4541                                      Diabetes130US        1
# 41514  41514                             Diabetes(scikit-learn)        1
# 42106  42106                                     uci_diabetes_p        1
# 42994  42994                               early-stage-diabetes        1
# 43063  43063                                           Diabetes        6
# 43321  43321                                DiabetesDataset2019        1
# 43341  43341                              Diabetes-Dataset-2019        1
# 43384  43384                                  Diabetes-Data-Set        1
# 43483  43483                      Pima-Indians-Diabetes-Dataset        1
# 43582  43582                              Pima-Indians-Diabetes        1
# ...

# %%
df_out.to_csv("data_name_30.csv")
