# %%
from scipy.stats import wilcoxon
import math
import pandas as pd
import numpy as np
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('../output_csv/df_mean_time.csv')
train_list=["RF_mean_train","GB_mean_train","DT_mean_train","SVM_mean_train","ET_mean_train","AB_mean_train"]
test_list=["RF_mean_test","GB_mean_test","DT_mean_test","SVM_mean_test","ET_mean_test","AB_mean_test"]
df_train=df[train_list]
df_test=df[test_list]

# %%
df_test.describe().round(4)
# Out:
#        RF_mean_test  GB_mean_test  DT_mean_test  SVM_mean_test  ET_mean_test  \
# count      194.0000      194.0000      194.0000       194.0000      194.0000
# mean         0.0128        0.0109        0.0009         0.2592        0.0150
# std          0.0115        0.0376        0.0007         1.0468        0.0151
# min          0.0063        0.0004        0.0005         0.0001        0.0038
# 25%          0.0075        0.0013        0.0007         0.0006        0.0052
# 50%          0.0085        0.0024        0.0007         0.0063        0.0099
# 75%          0.0122        0.0059        0.0008         0.1012        0.0209
# max          0.0820        0.3701        0.0069         9.4621        0.0990
#
#        AB_mean_test
# count      194.0000
# mean         0.0381
# std          0.0609
# min          0.0010
# 25%          0.0147
# 50%          0.0206
# 75%          0.0361
# max          0.5879

# %%
df_train.describe().round(4)
# Out:
#        RF_mean_train  GB_mean_train  DT_mean_train  SVM_mean_train  \
# count       194.0000       194.0000       194.0000        194.0000
# mean          3.6208         7.5000         0.0492          7.9558
# std           7.7354        24.6930         0.1184         42.0713
# min           0.0603         0.0578         0.0008          0.0005
# 25%           0.1213         0.2410         0.0013          0.0070
# 50%           0.4340         0.8461         0.0051          0.0909
# 75%           2.5244         4.2134         0.0333          1.2169
# max          59.1373       187.7492         0.8949        442.2317
#
#        ET_mean_train  AB_mean_train
# count       194.0000       194.0000
# mean          0.7180         7.2573
# std           1.9457        14.6902
# min           0.0698         0.0173
# 25%           0.1059         0.3295
# 50%           0.1635         1.1025
# 75%           0.4971         6.5243
# max          21.3886       109.1972

# %%
model_list=["RF_mean_train","GB_mean_train"]
plt.figure(figsize=(15,10))
sns.violinplot(data=df[model_list],orient="v")
plt.ylabel("mean train time")
plt.xlabel("Comparing mean train time over 200 datasets")
plt.show()

# %%
model_list=["RF_mean_test","GB_mean_test"]
plt.figure(figsize=(15,10))
sns.violinplot(data=df[model_list],orient="v")
plt.ylabel("mean test time")
plt.xlabel("Comparing mean test time over 200 datasets")
plt.show()

# %%
model_list=["AB_mean_train","GB_mean_train"]
plt.figure(figsize=(15,10))
sns.violinplot(data=df[model_list],orient="v")
plt.ylabel("mean train time")
plt.xlabel("Comparing mean train time over 200 datasets")
plt.show()

# %%
model_list=["AB_mean_test","GB_mean_test"]
plt.figure(figsize=(15,10))
sns.violinplot(data=df[model_list],orient="v")
plt.ylabel("mean test time")
plt.xlabel("Comparing mean test time over 200 datasets")
plt.show()

# %%
model_list=["AB_mean_train","ET_mean_train"]
plt.figure(figsize=(15,10))
sns.violinplot(data=df[model_list],orient="v")
plt.ylabel("mean train time")
plt.xlabel("Comparing mean train time over 200 datasets")
plt.show()

# %%
model_list=["AB_mean_test","ET_mean_test"]
plt.figure(figsize=(15,10))
sns.violinplot(data=df[model_list],orient="v")
plt.ylabel("mean test time")
plt.xlabel("Comparing mean test time over 200 datasets")
plt.show()
