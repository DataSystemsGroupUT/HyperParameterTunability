# %%
from scipy.stats import wilcoxon
import math
import pandas as pd
import numpy as np
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
warnings.filterwarnings('ignore')
# %matplotlib inline
font = {
        # 'family' : 'normal',

        'size'   : 18}

matplotlib.rc('font', **font)

# %%
df=pd.read_csv('../output_csv/cls_statistic.csv')
model_list=["AB_std","ET_std","RF_std","GB_std","DT_std","SVM_std"]
plt.figure(figsize=(12,10))
sns.violinplot(data=df[model_list],orient="v")
plt.ylabel("Standard Deviations")
plt.xlabel("Classifiers");
plt.savefig("../output_plots/standard_deviations.pdf" ,bbox_inches = 'tight',pad_inches = 0, format='pdf')
